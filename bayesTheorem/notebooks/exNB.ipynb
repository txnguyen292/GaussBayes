# %%
import pandas as pd
import numpy as np

import sys
sys.path.insert(0, "../src")
from config import CONFIG

# %load_ext autoreload
# %autoreload 2
data = pd.read_csv(CONFIG.data / "exNB.csv", header=None)

data.head()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#            0           1    2
# 0  75.626754  181.704486  1.0
# 1  70.540408  176.177640  1.0
# 2  76.875023  178.667364  1.0
# 3  70.225610  157.504877  1.0
# 4  74.106298  168.525499  1.0

# %%
X = data.iloc[:, :2].to_numpy()
y = data.iloc[:, -1].to_numpy()

# %%
from GaussNB import GaussNB
gnb = GaussNB()

# %%
gnb.fit(X, y)

# %%
y_hat = gnb.predict(X)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(X[:,0], X[:, 1], c = y)

# %%
plt.figure()
plt.scatter(X[:,0], X[:,1], c=y_hat)

# %%
def accuracy(y, y_hat):
    return np.mean(y==y_hat)
print(f"Accuracy: {accuracy(y, y_hat):0.3f}")
# Out:
# Accuracy: 0.986

# %%
xor = pd.read_csv(CONFIG.data / "xor.csv", sep = ",")
xor.head()
# Out:
#          x1        x2  y
# 0  1.907567  0.325865  0
# 1  2.270544  2.258817  0
# 2  2.323086  1.466601  0
# 3  0.752419  2.684305  0
# 4  2.837229  2.238149  0

# %%
# %load_ext autoreload
# %autoreload 2
from GaussNB import GaussBayes
gb = GaussBayes()
X = xor.iloc[:, :2].to_numpy()
y = xor.iloc[:, -1].to_numpy()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
gb.fit(X,y)

# %%
y_hat_gb=gb.predict(X)

# %%
accuracy(y, y_hat_gb)
# Out:
# 0.95825
